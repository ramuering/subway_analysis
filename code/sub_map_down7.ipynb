# %%
import folium
import pandas as pd

data=[
  {"line": "07호선", "name": "군자", "code": 2727,
        "lat": 37.557121, "lng": 127.079542,"lev":134.5},
    {"line": "07호선", "name": "강남구청", "code": 2732,
        "lat": 37.517186, "lng": 127.04128,"lev":72.3},
    {"line": "07호선", "name": "학동", "code": 2733,
        "lat": 37.514229, "lng": 127.031656,"lev":60.2},
    {"line": "07호선", "name": "논현", "code": 2734,
        "lat": 37.511093, "lng": 127.021415,"lev":49.4},
    {"line": "07호선", "name": "반포", "code": 2735,
        "lat": 37.508178, "lng": 127.011727,"lev":51.8},
    {"line": "07호선", "name": "고속터미널", "code": 2736,
        "lat": 37.50481, "lng": 127.004943,"lev":45.6},
    {"line": "07호선", "name": "내방", "code": 2737,
        "lat": 37.487618, "lng": 126.993513,"lev":43.1},
    {"line": "07호선", "name": "이수", "code": 2738,
        "lat": 37.486263, "lng": 126.981989,"lev":0},
    {"line": "07호선", "name": "까치울", "code": 2753,
        "lat": 37.506207, "lng": 126.810939,"lev":46.4},
    {"line": "07호선", "name": "부천종합운동장", "code": 2754,
        "lat": 37.50538, "lng": 126.797337,"lev":45.6},
    {"line": "07호선", "name": "춘의", "code": 2755,
        "lat": 37.503663, "lng": 126.787036,"lev":31.4},
    {"line": "07호선", "name": "부평구청", "code": 2761,
        "lat": 37.508336, "lng": 126.720548,"lev":0},
    {"line": "07호선", "name": "사가정", "code": 2724,
        "lat": 37.580894, "lng": 127.088478,"lev":128.3},
    {"line": "07호선", "name": "용마산", "code": 2725,
        "lat": 37.573647, "lng": 127.086727,"lev":132.3},
    {"line": "07호선", "name": "중곡", "code": 2726,
        "lat": 37.565923, "lng": 127.08432,"lev":136.6},
    {"line": "07호선", "name": "어린이대공원", "code": 2728,
        "lat": 37.548014, "lng": 127.074658,"lev":132},
    {"line": "07호선", "name": "남성", "code": 2739,
        "lat": 37.484596, "lng": 126.971251,"lev":45.2},
    {"line": "07호선", "name": "숭실대입구", "code": 2740,
        "lat": 37.496029, "lng": 126.953822,"lev":46.2},
    {"line": "07호선", "name": "상도", "code": 2741,
        "lat": 37.502834, "lng": 126.94791,"lev":48},
    {"line": "07호선", "name": "장승배기", "code": 2742,
        "lat": 37.504898, "lng": 126.93915,"lev":49.9},
    {"line": "07호선", "name": "신대방삼거리", "code": 2743,
        "lat": 37.499701, "lng": 126.928276,"lev":52.2},
    {"line": "07호선", "name": "보라매", "code": 2744,
        "lat": 37.499872, "lng": 126.920428,"lev":50.3},
    {"line": "07호선", "name": "신풍", "code": 2745, "lat": 37.50008, "lng": 126.90993,"lev":54.3},
    {"line": "07호선", "name": "대림", "code": 2746,
        "lat": 37.49297, "lng": 126.895801,"lev":59.9},
    {"line": "07호선", "name": "남구로", "code": 2747,
        "lat": 37.486056, "lng": 126.887249,"lev":59.7},
    {"line": "07호선", "name": "가산디지털단지", "code": 2748,
        "lat": 37.481072, "lng": 126.882343,"lev":31.2},
    {"line": "07호선", "name": "철산", "code": 2749,
        "lat": 37.47605, "lng": 126.867911,"lev":32},
    {"line": "07호선", "name": "광명사거리", "code": 2750,
        "lat": 37.479252, "lng": 126.854876,"lev":35.1},
    {"line": "07호선", "name": "천왕", "code": 2751,
        "lat": 37.486637, "lng": 126.838713,"lev":38.1},
    {"line": "07호선", "name": "온수", "code": 2752,
        "lat": 37.492258, "lng": 126.823388,"lev":38},
    {"line": "07호선", "name": "장암", "code": 2711,
        "lat": 37.700109, "lng": 127.053196,"lev":5.3},
    {"line": "07호선", "name": "중화", "code": 2721,
        "lat": 37.602545, "lng": 127.079264,"lev":96.4},
    {"line": "07호선", "name": "상봉", "code": 2722,
        "lat": 37.596362, "lng": 127.085032,"lev":114.4},
    {"line": "07호선", "name": "면목", "code": 2723,
        "lat": 37.588579, "lng": 127.087503,"lev":120.3},
    {"line": "07호선", "name": "건대입구", "code": 2729,
        "lat": 37.540693, "lng": 127.07023,"lev":104.1},
    {"line": "07호선", "name": "뚝섬유원지", "code": 2730,
        "lat": 37.53154, "lng": 127.066704,"lev":108.4},
    {"line": "07호선", "name": "청담", "code": 2731,
        "lat": 37.519365, "lng": 127.05335,"lev":94.6},
    {"line": "07호선", "name": "도봉산", "code": 2712,
        "lat": 37.689313, "lng": 127.046222,"lev":24.2},
    {"line": "07호선", "name": "수락산", "code": 2713,
        "lat": 37.67785, "lng": 127.055315,"lev":34.3},
    {"line": "07호선", "name": "마들", "code": 2714,
        "lat": 37.66494, "lng": 127.057675,"lev":46.6},
    {"line": "07호선", "name": "노원", "code": 2715,
        "lat": 37.655128, "lng": 127.061368,"lev":55.1},
    {"line": "07호선", "name": "중계", "code": 2716,
        "lat": 37.644583, "lng": 127.064303,"lev":66.2},
    {"line": "07호선", "name": "하계", "code": 2717,
        "lat": 37.636352, "lng": 127.06799,"lev":78},
    {"line": "07호선", "name": "공릉", "code": 2718,
        "lat": 37.625742, "lng": 127.072896,"lev":84.9},
    {"line": "07호선", "name": "태릉입구", "code": 2719,
        "lat": 37.617983, "lng": 127.07512,"lev":83.2},
    {"line": "07호선", "name": "먹골", "code": 2720,
        "lat": 37.610637, "lng": 127.077725,"lev":90.1},
    {"line": "07호선", "name": "신중동", "code": 2756,
        "lat": 37.503048, "lng": 126.77596,"lev":27.3},
    {"line": "07호선", "name": "부천시청", "code": 2757,
        "lat": 37.504631, "lng": 126.763538,"lev":24.7},
    {"line": "07호선", "name": "상동", "code": 2758,
        "lat": 37.505781, "lng": 126.753083,"lev":23.1},
    {"line": "07호선", "name": "삼산체육관", "code": 2759,
        "lat": 37.506411, "lng": 126.742153,"lev":24.4},
    {"line": "07호선", "name": "굴포천", "code": 2760,
        "lat": 37.506997, "lng": 126.73128,"lev":24.4}
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)
# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['lev']
    # 색상 설정
    if reservoir_ratio >= 90:
       fill_color = 'red'
    elif 90>reservoir_ratio>=50:
       fill_color = 'orange'
    elif reservoir_ratio==0:
      fill_color = 'gray'
    else:
        fill_color='green'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['lev']}<br>
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
