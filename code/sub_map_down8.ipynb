# %%
import folium 
import pandas as pd

data=[
  {"line": "08호선", "name": "암사", "code": 2811,
        "lat": 37.55021, "lng": 127.127562, "lev":51.4},
    {"line": "08호선", "name": "천호", "code": 2812,
        "lat": 37.538397, "lng": 127.123572, "lev":119.7},
    {"line": "08호선", "name": "강동구청", "code": 2813,
        "lat": 37.530341, "lng": 127.120508, "lev": 131.2},
    {"line": "08호선", "name": "몽촌토성", "code": 2814,
        "lat": 37.517409, "lng": 127.112359, "lev":127},
    {"line": "08호선", "name": "잠실", "code": 2815,
        "lat": 37.51395, "lng": 127.102234, "lev":112.2},
    {"line": "08호선", "name": "신흥", "code": 2825,
        "lat": 37.440918, "lng": 127.147564,"lev":21.9},
    {"line": "08호선", "name": "수진", "code": 2826,
        "lat": 37.437428, "lng": 127.140722, "lev":20.6},
    {"line": "08호선", "name": "모란", "code": 2827,
        "lat": 37.43213, "lng": 127.129087,"lev":0},
    {"line": "08호선", "name": "석촌", "code": 2816,
        "lat": 37.505431, "lng": 127.106979, "lev":113.1},
    {"line": "08호선", "name": "송파", "code": 2817,
        "lat": 37.499703, "lng": 127.112183,"lev":117.2},
    {"line": "08호선", "name": "가락시장", "code": 2818,
        "lat": 37.492522, "lng": 127.118234,"lev":96},
    {"line": "08호선", "name": "문정", "code": 2819, "lat": 37.485855, "lng": 127.1225, "lev":61},
    {"line": "08호선", "name": "장지", "code": 2820,
        "lat": 37.478703, "lng": 127.126191, "lev":55.5},
    {"line": "08호선", "name": "복정", "code": 2821,
        "lat": 37.470047, "lng": 127.126662,"lev":27.1},
    {"line": "08호선", "name": "산성", "code": 2822,
        "lat": 37.457122, "lng": 127.149908,"lev":24.1},
    {"line": "08호선", "name": "남한산성입구", "code": 2823,
        "lat": 37.451535, "lng": 127.159816,"lev":23.3},
    {"line": "08호선", "name": "단대오거리", "code": 2824,
        "lat": 37.44521, "lng": 127.156866,"lev":21.7}
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)

# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['lev']
    # 색상 설정
    if reservoir_ratio >= 100:
       fill_color = 'red'
    elif 100>reservoir_ratio>=50:
       fill_color = 'orange'
    elif reservoir_ratio==0:
      fill_color = 'gray'
    else:
        fill_color='green'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['lev']}<br>
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea8e36701e091925f07e134b17c14320 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea8e36701e091925f07e134b17c14320&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea8e36701e091925f07e134b17c14320 = L.map(
#                 &quot;map_ea8e36701e091925f07e134b17c14320&quot;,
#                 {
#                     center: [37.508725, 126.891295],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f277fc29a65f1eacecedcc1618703c68 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea8e36701e091925f07e134b17c14320);
#
#
#             var circle_marker_6c47b56deb61bd44cc712f73f90b12bb = L.circleMarker(
#                 [37.55021, 127.127562],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8e36701e091925f07e134b17c14320);
#
#
#         var popup_0e27ad2619879b434a8f474b4cf2f712 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_bf28bfe033d0a1dd19fbdfe18d8fb760 = $(`&lt;div id=&quot;html_bf28bfe033d0a1dd19fbdfe18d8fb760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;호선: &lt;/b&gt;08호선&lt;br&gt;&lt;b&gt;역 이름: &lt;/b&gt;암사&lt;br&gt;         &lt;b&gt;외부코드: &lt;/b&gt;2811&lt;br&gt;&lt;b&gt;위도: &lt;/b&gt;37.55021&lt;br&gt;         &lt;b&gt;경도: &lt;/b&gt;127.127562&lt;br&gt;&lt;b&gt;혼잡도: &lt;/b&gt;51.4&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_0e27ad2619879b434a8f474b4cf2f712.setContent(html_bf28bfe033d0a1dd19fbdfe18d8fb760);
#
#
#
#         circle_marker_6c47b56deb61bd44cc712f73f90b12bb.bindPopup(popup_0e27ad2619879b434a8f474b4cf2f712)
#         ;
#
#
#
#
#             var circle_marker_006c6fe1cb87b4f8a2b404ccb6b57de8 = L.circleMarker(
#                 [37.538397, 127.123572],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8e36701e091925f07e134b17c14320);
#
#
#         var popup_6765ccc2753b929244a21f50a65952f4 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_45193407a119450ddca9c3842e8034e2 = $(`&lt;div id=&quot;html_45193407a119450ddca9c3842e8034e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;호선: &lt;/b&gt;08호선&lt;br&gt;&lt;b&gt;역 이름: &lt;/b&gt;천호&lt;br&gt;         &lt;b&gt;외부코드: &lt;/b&gt;2812&lt;br&gt;&lt;b&gt;위도: &lt;/b&gt;37.538397&lt;br&gt;         &lt;b&gt;경도: &lt;/b&gt;127.123572&lt;br&gt;&lt;b&gt;혼잡도: &lt;/b&gt;119.7&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_6765ccc2753b929244a21f50a65952f4.setContent(html_45193407a119450ddca9c3842e8034e2);
#
#
#
#         circle_marker_006c6fe1cb87b4f8a2b404ccb6b57de8.bindPopup(popup_6765ccc2753b929244a21f50a65952f4)
#         ;
#
#
#
#
#             var circle_marker_f3124823820a539c4f54404504ac7552 = L.circleMarker(
#                 [37.530341, 127.120508],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ea8e36701e091925f07e134b17c14320);
#
#
#         var popup_47b44ba1499efa7fff584715af11e38f = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_a3f8f34aa1e60b04dd1f83f1bfae8a3a = $(`&lt;div id=&quot;html_a3f8f34aa1e60b04dd1f83f1bfae8a3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;호선: &lt;/b&gt;08호선&lt;br&gt;&lt;b&gt;역 이름: &lt;/b&gt;강동구청&lt;br&gt;         &lt;b&gt;외부코드: &lt;/
