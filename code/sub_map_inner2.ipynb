# %%
import folium
import pandas as pd
data=[
  {"line": "02호선", "name": "강변", "code": 214,
        "lat": 37.535095, "lng": 127.094681, "con": 73.3},
    {"line": "02호선", "name": "잠실나루", "code": 215,
        "lat": 37.520733, "lng": 127.10379, "con":69.1},
    {"line": "02호선", "name": "잠실", "code": 216,
        "lat": 37.51395, "lng": 127.102234, "con":92.5},
    {"line": "02호선", "name": "잠실새내", "code": 217,
        "lat": 37.511687, "lng": 127.086162, "con":100},
    {"line": "02호선", "name": "종합운동장", "code": 218,
        "lat": 37.510997, "lng": 127.073642, "con":97.8},
    {"line": "02호선", "name": "삼성", "code": 219,
        "lat": 37.508844, "lng": 127.06316, "con":81.9},
    {"line": "02호선", "name": "선릉", "code": 220,
        "lat": 37.504503, "lng": 127.049008, "con":79.9},
    {"line": "02호선", "name": "역삼", "code": 221,
        "lat": 37.500622, "lng": 127.036456, "con":61.6},
    {"line": "02호선", "name": "강남", "code": 222,
        "lat": 37.497175, "lng": 127.027926, "con":52},
    {"line": "02호선", "name": "교대", "code": 223,
        "lat": 37.493415, "lng": 127.01408, "con":49.8},
    {"line": "02호선", "name": "방배", "code": 225,
        "lat": 37.481426, "lng": 126.997596, "con":43.8},
    {"line": "02호선", "name": "사당", "code": 226,
        "lat": 37.47653, "lng": 126.981685, "con":44.6},
    {"line": "02호선", "name": "낙성대", "code": 227,
        "lat": 37.47693, "lng": 126.963693, "con":46.7},
    {"line": "02호선", "name": "서울대입구", "code": 228,
        "lat": 37.481247, "lng": 126.952739, "con":50.6},
    {"line": "02호선", "name": "봉천", "code": 229,
        "lat": 37.482362, "lng": 126.941892, "con":55.7},
    {"line": "02호선", "name": "신림", "code": 230,
        "lat": 37.484201, "lng": 126.929715, "con":71.2},
    {"line": "02호선", "name": "신대방", "code": 231,
        "lat": 37.487462, "lng": 126.913149, "con":80.6},
    {"line": "02호선", "name": "구로디지털단지", "code": 232,
        "lat": 37.485266, "lng": 126.901401, "con":87.7},
    {"line": "02호선", "name": "신도림", "code": 234,
        "lat": 37.508725, "lng": 126.891295, "con":121.2},
    {"line": "02호선", "name": "문래", "code": 235,
        "lat": 37.517933, "lng": 126.89476, "con":110.6},
    {"line": "02호선", "name": "영등포구청", "code": 236,
        "lat": 37.52497, "lng": 126.895951, "con":108.2},
    {"line": "02호선", "name": "용답", "code": 244,
        "lat": 37.561904, "lng": 127.050899, "con":0},
    {"line": "02호선", "name": "신정네거리", "code": 249,
        "lat": 37.520074, "lng": 126.852912, "con":0},
    {"line": "02호선", "name": "을지로입구", "code": 202,
        "lat": 37.566014, "lng": 126.982618, "con":62.5},
    {"line": "02호선", "name": "을지로3가", "code": 203,
        "lat": 37.566295, "lng": 126.99191, "con":59.4},
    {"line": "02호선", "name": "을지로4가", "code": 204,
        "lat": 37.566941, "lng": 126.998079, "con":52.4},
    {"line": "02호선", "name": "동대문역사문화", "code": 205,
        "lat": 37.565138, "lng": 127.007896, "con":74.1},
    {"line": "02호선", "name": "신당", "code": 206,
        "lat": 37.565972, "lng": 127.01782, "con":76.5},
    {"line": "02호선", "name": "한양대", "code": 209,
        "lat": 37.555273, "lng": 127.043655, "con":62.6},
    {"line": "02호선", "name": "뚝섬", "code": 210,
        "lat": 37.547184, "lng": 127.047367, "con":54},
    {"line": "02호선", "name": "성수", "code": 211,
        "lat": 37.544581, "lng": 127.055961, "con":43.9},
    {"line": "02호선", "name": "건대입구", "code": 212,
        "lat": 37.540693, "lng": 127.07023, "con":58.8},
    {"line": "02호선", "name": "구의", "code": 213,
        "lat": 37.537077, "lng": 127.085916, "con":62.6},
    {"line": "02호선", "name": "당산", "code": 237,
        "lat": 37.53438, "lng": 126.902281, "con":104.1},
    {"line": "02호선", "name": "합정", "code": 238,
        "lat": 37.549463, "lng": 126.913739, "con":96.6},
    {"line": "02호선", "name": "홍대입구", "code": 239,
        "lat": 37.557192, "lng": 126.925381, "con":106.1},
    {"line": "02호선", "name": "신촌", "code": 240,
        "lat": 37.555134, "lng": 126.936893, "con":100.7},
    {"line": "02호선", "name": "이대", "code": 241,
        "lat": 37.556733, "lng": 126.946013, "con":99.3},
    {"line": "02호선", "name": "아현", "code": 242,
        "lat": 37.557345, "lng": 126.956141, "con":102.4},
    {"line": "02호선", "name": "충정로", "code": 243,
        "lat": 37.559973, "lng": 126.963672, "con":102.6},
    {"line": "02호선", "name": "신답", "code": 245,
        "lat": 37.57004, "lng": 127.046481, "con":0},
    {"line": "02호선", "name": "까치산", "code": 200,
        "lat": 37.531768, "lng": 126.846683, "con":0},
    {"line": "02호선", "name": "시청", "code": 201,
        "lat": 37.564718, "lng": 126.977108, "con":89.4},
    {"line": "02호선", "name": "서초", "code": 224,
        "lat": 37.491897, "lng": 127.007917, "con":45},
    {"line": "02호선", "name": "왕십리", "code": 208,
        "lat": 37.561533, "lng": 127.037732, "con":67.5},
    {"line": "02호선", "name": "상왕십리", "code": 207,
        "lat": 37.564354, "lng": 127.029354, "con":81.3},
    {"line": "02호선", "name": "대림", "code": 233,
        "lat": 37.49297, "lng": 126.895801, "con":96.8},
    {"line": "02호선", "name": "신설동", "code": 246,
        "lat": 37.575297, "lng": 127.025087, "con":0},
    {"line": "02호선", "name": "도림천", "code": 247,
        "lat": 37.514287, "lng": 126.882768, "con":0},
    {"line": "02호선", "name": "양천구청", "code": 248,
        "lat": 37.512398, "lng": 126.865819, "con":0},
    {"line": "02호선", "name": "용두", "code": 250,
        "lat": 37.574028, "lng": 127.038091, "con":0},
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)

# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['con']
    # 색상 설정
    if reservoir_ratio >90:
       fill_color = 'red'
    elif reservoir_ratio > 60:
       fill_color = 'orange'
    elif reservoir_ratio >0:
       fill_color = 'green'
    elif reservoir_ratio ==0:
       fill_color='gray'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['con']}
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
