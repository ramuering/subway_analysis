# %%
import folium
import pandas as pd

data=[
  {"line": "06호선", "name": "망원", "code": 2622,
        "lat": 37.556094, "lng": 126.910052, "lev":106.1},
    {"line": "06호선", "name": "합정", "code": 2623,
        "lat": 37.549463, "lng": 126.913739, "lev":58},
    {"line": "06호선", "name": "상수", "code": 2624,
        "lat": 37.547716, "lng": 126.922852, "lev":56.2},
    {"line": "06호선", "name": "광흥창", "code": 2625,
        "lat": 37.547456, "lng": 126.931993,"lev":55.9},
    {"line": "06호선", "name": "대흥", "code": 2626,
        "lat": 37.547771, "lng": 126.942069,"lev":53.2},
    {"line": "06호선", "name": "버티고개", "code": 2633,
        "lat": 37.548013, "lng": 127.007055,"lev":29.8},
    {"line": "06호선", "name": "약수", "code": 2634,
        "lat": 37.55434, "lng": 127.010655,"lev":28},
    {"line": "06호선", "name": "청구", "code": 2635,
        "lat": 37.560245, "lng": 127.013828,"lev":30.2},
    {"line": "06호선", "name": "신당", "code": 2636,
        "lat": 37.565972, "lng": 127.01782,"lev":33.2},
    {"line": "06호선", "name": "응암", "code": 2611,
        "lat": 37.598605, "lng": 126.915577,"lev":67.2},
    {"line": "06호선", "name": "역촌", "code": 2612,
        "lat": 37.606021, "lng": 126.922744,"lev":24.7},
    {"line": "06호선", "name": "불광", "code": 2613,
        "lat": 37.610469, "lng": 126.929887,"lev":9.7},
    {"line": "06호선", "name": "독바위", "code": 2614,
        "lat": 37.618456, "lng": 126.933031,"lev":14},
    {"line": "06호선", "name": "연신내", "code": 2615,
        "lat": 37.619001, "lng": 126.921008,"lev":37},
    {"line": "06호선", "name": "구산", "code": 2616,
        "lat": 37.611377, "lng": 126.91727,"lev":47.6},
    {"line": "06호선", "name": "새절", "code": 2617,
        "lat": 37.591148, "lng": 126.913629,"lev":85.2},
    {"line": "06호선", "name": "증산", "code": 2618,
        "lat": 37.583876, "lng": 126.909645,"lev":94.9},
    {"line": "06호선", "name": "디지털미디어시티", "code": 2619,
        "lat": 37.576646, "lng": 126.900984,"lev":93},
    {"line": "06호선", "name": "월드컵경기장", "code": 2620,
        "lat": 37.569532, "lng": 126.899298,"lev":92},
    {"line": "06호선", "name": "마포구청", "code": 2621,
        "lat": 37.563515, "lng": 126.903343,"lev":100.4},
    {"line": "06호선", "name": "공덕", "code": 2627,
        "lat": 37.544018, "lng": 126.951592,"lev":50.6},
    {"line": "06호선", "name": "효창공원앞", "code": 2628,
        "lat": 37.539261, "lng": 126.961351,"lev":52},
    {"line": "06호선", "name": "삼각지", "code": 2629,
        "lat": 37.534777, "lng": 126.97311,"lev":37.9},
    {"line": "06호선", "name": "녹사평", "code": 2630,
        "lat": 37.534675, "lng": 126.986695,"lev":36.3},
    {"line": "06호선", "name": "이태원", "code": 2631,
        "lat": 37.534488, "lng": 126.994302,"lev":34.4},
    {"line": "06호선", "name": "한강진", "code": 2632,
        "lat": 37.539631, "lng": 127.001725,"lev":29},
    {"line": "06호선", "name": "동묘앞", "code": 2637,
        "lat": 37.572627, "lng": 127.016429,"lev":28.7},
    {"line": "06호선", "name": "창신", "code": 2638,
        "lat": 37.579661, "lng": 127.015241,"lev":28.3},
    {"line": "06호선", "name": "보문", "code": 2639,
        "lat": 37.585286, "lng": 127.019381,"lev":29.4},
    {"line": "06호선", "name": "안암", "code": 2640,
        "lat": 37.586272, "lng": 127.029005,"lev":23.1},
    {"line": "06호선", "name": "고려대", "code": 2641,
        "lat": 37.590508, "lng": 127.036296,"lev":20.5},
    {"line": "06호선", "name": "월곡", "code": 2642,
        "lat": 37.601948, "lng": 127.041518,"lev":20.2},
    {"line": "06호선", "name": "상월곡", "code": 2643,
        "lat": 37.606377, "lng": 127.048491,"lev":16.1},
    {"line": "06호선", "name": "돌곶이", "code": 2644,
        "lat": 37.610537, "lng": 127.056431,"lev":15.8},
    {"line": "06호선", "name": "석계", "code": 2645,
        "lat": 37.614805, "lng": 127.065851,"lev":19.6},
    {"line": "06호선", "name": "태릉입구", "code": 2646,
        "lat": 37.617983, "lng": 127.07512,"lev":9.4},
    {"line": "06호선", "name": "화랑대", "code": 2647,
        "lat": 37.620064, "lng": 127.084689, "lev":3.9},
    {"line": "06호선", "name": "봉화산", "code": 2648,
        "lat": 37.617283, "lng": 127.091401,"lev":0},
    {"line": "06호선", "name": "신내", "code": 2649,
        "lat": 37.612887, "lng": 127.103218, "lev":0}
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)
# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['lev']
    # 색상 설정
    if reservoir_ratio >= 60:
       fill_color = 'red'
    elif 60>reservoir_ratio>=30:
       fill_color = 'orange'
    elif reservoir_ratio==0:
      fill_color = 'gray'
    else:
        fill_color='green'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['lev']}<br>
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab967c81baee00d411e287677b4368d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab967c81baee00d411e287677b4368d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab967c81baee00d411e287677b4368d4 = L.map(
#                 &quot;map_ab967c81baee00d411e287677b4368d4&quot;,
#                 {
#                     center: [37.508725, 126.891295],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0da0eb29511be56b1c4021624c6a3a0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab967c81baee00d411e287677b4368d4);
#
#
#             var circle_marker_429cebb92977aaad40cc03eb59bbd176 = L.circleMarker(
#                 [37.556094, 126.910052],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ab967c81baee00d411e287677b4368d4);
#
#
#         var popup_363aac6ae1e9d99952216334ac1542b1 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_8590c910752cc13fe40e472fa178eab1 = $(`&lt;div id=&quot;html_8590c910752cc13fe40e472fa178eab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;호선: &lt;/b&gt;06호선&lt;br&gt;&lt;b&gt;역 이름: &lt;/b&gt;망원&lt;br&gt;         &lt;b&gt;외부코드: &lt;/b&gt;2622&lt;br&gt;&lt;b&gt;위도: &lt;/b&gt;37.556094&lt;br&gt;         &lt;b&gt;경도: &lt;/b&gt;126.910052&lt;br&gt;&lt;b&gt;혼잡도: &lt;/b&gt;106.1&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_363aac6ae1e9d99952216334ac1542b1.setContent(html_8590c910752cc13fe40e472fa178eab1);
#
#
#
#         circle_marker_429cebb92977aaad40cc03eb59bbd176.bindPopup(popup_363aac6ae1e9d99952216334ac1542b1)
#         ;
#
#
#
#
#             var circle_marker_f6fc5c95b46587f321411f0db66d4a72 = L.circleMarker(
#                 [37.549463, 126.913739],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ab967c81baee00d411e287677b4368d4);
#
#
#         var popup_682e8f9a54718bb94359bfca639470d7 = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_edf33f942f58382f7a84968a649380d0 = $(`&lt;div id=&quot;html_edf33f942f58382f7a84968a649380d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;호선: &lt;/b&gt;06호선&lt;br&gt;&lt;b&gt;역 이름: &lt;/b&gt;합정&lt;br&gt;         &lt;b&gt;외부코드: &lt;/b&gt;2623&lt;br&gt;&lt;b&gt;위도: &lt;/b&gt;37.549463&lt;br&gt;         &lt;b&gt;경도: &lt;/b&gt;126.913739&lt;br&gt;&lt;b&gt;혼잡도: &lt;/b&gt;58&lt;br&gt;     &lt;/div&gt;`)[0];
#                 popup_682e8f9a54718bb94359bfca639470d7.setContent(html_edf33f942f58382f7a84968a649380d0);
#
#
#
#         circle_marker_f6fc5c95b46587f321411f0db66d4a72.bindPopup(popup_682e8f9a54718bb94359bfca639470d7)
#         ;
#
#
#
#
#             var circle_marker_d7d79294f069f465d447a006bf7422df = L.circleMarker(
#                 [37.547716, 126.922852],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_ab967c81baee00d411e287677b4368d4);
#
#
#         var popup_2ce77645e4aced1f164480036d7e118e = L.popup({&quot;maxWidth&quot;: 400});
#
#
#
#                 var html_a515528974943df88630d55c08446741 = $(`&lt;div id=&quot;html_a515528974943df88630d55c08446741&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;호선: &lt;/b&gt;06호선&lt;br&gt;&lt;b&gt;역 이름: &lt;/b&gt;상수&lt;br&gt;         &lt;b&gt;외부코드: &lt;
