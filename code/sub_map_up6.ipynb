# %%
import folium
import pandas as pd

data=[
  {"line": "06호선", "name": "망원", "code": 2622,
        "lat": 37.556094, "lng": 126.910052, "lev":27.5},
    {"line": "06호선", "name": "합정", "code": 2623,
        "lat": 37.549463, "lng": 126.913739, "lev":29.7},
    {"line": "06호선", "name": "상수", "code": 2624,
        "lat": 37.547716, "lng": 126.922852, "lev":20.3},
    {"line": "06호선", "name": "광흥창", "code": 2625,
        "lat": 37.547456, "lng": 126.931993,"lev":21.7},
    {"line": "06호선", "name": "대흥", "code": 2626,
        "lat": 37.547771, "lng": 126.942069,"lev":21.8},
    {"line": "06호선", "name": "버티고개", "code": 2633,
        "lat": 37.548013, "lng": 127.007055,"lev":44.7},
    {"line": "06호선", "name": "약수", "code": 2634,
        "lat": 37.55434, "lng": 127.010655,"lev":44.1},
    {"line": "06호선", "name": "청구", "code": 2635,
        "lat": 37.560245, "lng": 127.013828,"lev":63.5},
    {"line": "06호선", "name": "신당", "code": 2636,
        "lat": 37.565972, "lng": 127.01782,"lev":66.5},
    {"line": "06호선", "name": "응암", "code": 2611,
        "lat": 37.598605, "lng": 126.915577,"lev":22.5},
    {"line": "06호선", "name": "역촌", "code": 2612,
        "lat": 37.606021, "lng": 126.922744,"lev":0},
    {"line": "06호선", "name": "불광", "code": 2613,
        "lat": 37.610469, "lng": 126.929887,"lev":0},
    {"line": "06호선", "name": "독바위", "code": 2614,
        "lat": 37.618456, "lng": 126.933031,"lev":0},
    {"line": "06호선", "name": "연신내", "code": 2615,
        "lat": 37.619001, "lng": 126.921008,"lev":0},
    {"line": "06호선", "name": "구산", "code": 2616,
        "lat": 37.611377, "lng": 126.91727,"lev":0},
    {"line": "06호선", "name": "새절", "code": 2617,
        "lat": 37.591148, "lng": 126.913629,"lev":15},
    {"line": "06호선", "name": "증산", "code": 2618,
        "lat": 37.583876, "lng": 126.909645,"lev":15.4},
    {"line": "06호선", "name": "디지털미디어시티", "code": 2619,
        "lat": 37.576646, "lng": 126.900984,"lev":15.3},
    {"line": "06호선", "name": "월드컵경기장", "code": 2620,
        "lat": 37.569532, "lng": 126.899298,"lev":23.3},
    {"line": "06호선", "name": "마포구청", "code": 2621,
        "lat": 37.563515, "lng": 126.903343,"lev":25.7},
    {"line": "06호선", "name": "공덕", "code": 2627,
        "lat": 37.544018, "lng": 126.951592,"lev":24.6},
    {"line": "06호선", "name": "효창공원앞", "code": 2628,
        "lat": 37.539261, "lng": 126.961351,"lev":41.7},
    {"line": "06호선", "name": "삼각지", "code": 2629,
        "lat": 37.534777, "lng": 126.97311,"lev":43.3},
    {"line": "06호선", "name": "녹사평", "code": 2630,
        "lat": 37.534675, "lng": 126.986695,"lev":39.9},
    {"line": "06호선", "name": "이태원", "code": 2631,
        "lat": 37.534488, "lng": 126.994302,"lev":40.7},
    {"line": "06호선", "name": "한강진", "code": 2632,
        "lat": 37.539631, "lng": 127.001725,"lev":40.4},
    {"line": "06호선", "name": "동묘앞", "code": 2637,
        "lat": 37.572627, "lng": 127.016429,"lev":86.9},
    {"line": "06호선", "name": "창신", "code": 2638,
        "lat": 37.579661, "lng": 127.015241,"lev":94.9},
    {"line": "06호선", "name": "보문", "code": 2639,
        "lat": 37.585286, "lng": 127.019381,"lev":92.9},
    {"line": "06호선", "name": "안암", "code": 2640,
        "lat": 37.586272, "lng": 127.029005,"lev":82.7},
    {"line": "06호선", "name": "고려대", "code": 2641,
        "lat": 37.590508, "lng": 127.036296,"lev":85.1},
    {"line": "06호선", "name": "월곡", "code": 2642,
        "lat": 37.601948, "lng": 127.041518,"lev":89.8},
    {"line": "06호선", "name": "상월곡", "code": 2643,
        "lat": 37.606377, "lng": 127.048491,"lev":70.8},
    {"line": "06호선", "name": "돌곶이", "code": 2644,
        "lat": 37.610537, "lng": 127.056431,"lev":66.2},
    {"line": "06호선", "name": "석계", "code": 2645,
        "lat": 37.614805, "lng": 127.065851,"lev":58.5},
    {"line": "06호선", "name": "태릉입구", "code": 2646,
        "lat": 37.617983, "lng": 127.07512,"lev":54.7},
    {"line": "06호선", "name": "화랑대", "code": 2647,
        "lat": 37.620064, "lng": 127.084689, "lev":33.8},
    {"line": "06호선", "name": "봉화산", "code": 2648,
        "lat": 37.617283, "lng": 127.091401,"lev":14.9},
    {"line": "06호선", "name": "신내", "code": 2649,
        "lat": 37.612887, "lng": 127.103218, "lev":0}
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)
# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['lev']
    # 색상 설정
    if reservoir_ratio >= 60:
       fill_color = 'red'
    elif 60>reservoir_ratio>=30:
       fill_color = 'orange'
    elif reservoir_ratio==0:
      fill_color = 'gray'
    else:
        fill_color='green'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['lev']}<br>
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
