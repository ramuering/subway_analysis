# %%
import folium
import pandas as pd

data=[
  {"line": "03호선", "name": "양재", "code": 332,
        "lat": 37.484147, "lng": 127.034631, "con":35.8},
    {"line": "03호선", "name": "매봉", "code": 333,
        "lat": 37.486947, "lng": 127.046769, "con":29.2},
    {"line": "03호선", "name": "도곡", "code": 334,
        "lat": 37.490858, "lng": 127.055381, "con":23.1},
    {"line": "03호선", "name": "대치", "code": 335,
        "lat": 37.494612, "lng": 127.063642, "con":22.2},
    {"line": "03호선", "name": "학여울", "code": 336,
        "lat": 37.496663, "lng": 127.070594, "con":21.9},
    {"line": "03호선", "name": "대청", "code": 337,
        "lat": 37.493514, "lng": 127.079532, "con":21.8},
    {"line": "03호선", "name": "일원", "code": 338,
        "lat": 37.483681, "lng": 127.08439, "con":17.3},
    {"line": "03호선", "name": "수서", "code": 339,
        "lat": 37.487371, "lng": 127.10188, "con":16.1},
    {"line": "03호선", "name": "동대입구", "code": 322,
        "lat": 37.559052, "lng": 127.005602, "con":81.8},
    {"line": "03호선", "name": "금호", "code": 324,
        "lat": 37.548034, "lng": 127.015872, "con":98.7},
    {"line": "03호선", "name": "옥수", "code": 325,
        "lat": 37.540685, "lng": 127.017965, "con":105},
    {"line": "03호선", "name": "압구정", "code": 326,
        "lat": 37.527072, "lng": 127.028461, "con":89.8},
    {"line": "03호선", "name": "신사", "code": 327,
        "lat": 37.516334, "lng": 127.020114, "con":80.1},
    {"line": "03호선", "name": "잠원", "code": 328,
        "lat": 37.512759, "lng": 127.01122, "con":81.7},
    {"line": "03호선", "name": "고속", "code": 329,
        "lat": 37.50481, "lng": 127.004943, "con":107},
    {"line": "03호선", "name": "교대", "code": 330,
        "lat": 37.493415, "lng": 127.01408, "con":93.4},
    {"line": "03호선", "name": "남부터미널", "code": 331,
        "lat": 37.485013, "lng": 127.016189, "con":77.5},
    {"line": "03호선", "name": "경복궁", "code": 317,
        "lat": 37.575762, "lng": 126.97353, "con":132.9},
    {"line": "03호선", "name": "안국", "code": 318,
        "lat": 37.576477, "lng": 126.985443, "con":124},
    {"line": "03호선", "name": "종로3가", "code": 319,
        "lat": 37.571607, "lng": 126.991806, "con":100.1},
    {"line": "03호선", "name": "을지로3가", "code": 320,
        "lat": 37.566295, "lng": 126.99191, "con":75.9},
    {"line": "03호선", "name": "지축", "code": 309,
        "lat": 37.648048, "lng": 126.913951, "con":81.3},
    {"line": "03호선", "name": "구파발", "code": 310,
        "lat": 37.636763, "lng": 126.918821, "con":76.4},
    {"line": "03호선", "name": "연신내", "code": 311,
        "lat": 37.619001, "lng": 126.921008, "con":99.2},
    {"line": "03호선", "name": "불광", "code": 312,
        "lat": 37.610469, "lng": 126.929887, "con":120.9},
    {"line": "03호선", "name": "녹번", "code": 313,
        "lat": 37.600927, "lng": 126.935756, "con":126.8},
    {"line": "03호선", "name": "홍제", "code": 314,
        "lat": 37.589066, "lng": 126.943736, "con":143.8},
    {"line": "03호선", "name": "무악재", "code": 315,
        "lat": 37.582299, "lng": 126.950291, "con":139.8},
    {"line": "03호선", "name": "독립문", "code": 316,
        "lat": 37.574571, "lng": 126.957748, "con":139.5},
    {"line": "03호선", "name": "가락시장", "code": 340,
        "lat": 37.492522, "lng": 127.118234, "con":11.3},
    {"line": "03호선", "name": "경찰병원", "code": 341,
        "lat": 37.495918, "lng": 127.12454, "con":7.9},
    {"line": "03호선", "name": "오금", "code": 342,
        "lat": 37.502162, "lng": 127.128111, "con":24},
    {"line": "03호선", "name": "원당", "code": 1951,
        "lat": 37.653324, "lng": 126.843041, "con":0},
    {"line": "03호선", "name": "대곡", "code": 1953,
        "lat": 37.631626, "lng": 126.811024, "con":0},
    {"line": "03호선", "name": "백석", "code": 1954,
        "lat": 37.643114, "lng": 126.78787, "con":0},
    {"line": "03호선", "name": "마두", "code": 1955,
        "lat": 37.652206, "lng": 126.77762, "con":0},
    {"line": "03호선", "name": "정발산", "code": 1956,
        "lat": 37.659477, "lng": 126.773359, "con":0},
    {"line": "03호선", "name": "주엽", "code": 1957,
        "lat": 37.670072, "lng": 126.761334, "con":0},
    {"line": "03호선", "name": "대화", "code": 1958,
        "lat": 37.676087, "lng": 126.747569, "con":0},
    {"line": "03호선", "name": "원흥", "code": 1948,
        "lat": 37.650658, "lng": 126.872642, "con":0},
    {"line": "03호선", "name": "삼송", "code": 1950,
        "lat": 37.653083, "lng": 126.895558, "con":0},
    {"line": "03호선", "name": "약수", "code": 323,
        "lat": 37.55434, "lng": 127.010655, "con":96.6},
    {"line": "03호선", "name": "충무로", "code": 321,
        "lat": 37.561243, "lng": 126.99428, "con":87.1},
    {"line": "03호선", "name": "화정", "code": 1952,
        "lat": 37.634592, "lng": 126.83265, "con":0}
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)
# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['con']
    # 색상 설정
    if reservoir_ratio >90:
       fill_color = 'red'
    elif reservoir_ratio > 40:
       fill_color = 'orange'
    elif reservoir_ratio >0:
       fill_color = 'green'
    elif reservoir_ratio ==0:
       fill_color='gray'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['con']}
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
