# %%
import folium
import pandas as pd

data=[
  {"line": "05호선", "name": "종로3가", "code": 2535,
        "lat": 37.571607, "lng": 126.991806, "con":76.3},
    {"line": "05호선", "name": "둔촌동", "code": 2555,
        "lat": 37.527788, "lng": 127.136248, "con":55.3},
    {"line": "05호선", "name": "올림픽공원", "code": 2556,
        "lat": 37.516078, "lng": 127.130848, "con":49.4},
    {"line": "05호선", "name": "미사", "code": 2563,
        "lat": 37.553096, "lng": 127.183245, "con":0},
    {"line": "05호선", "name": "하남풍산", "code": 2564,
        "lat": 37.542134, "lng": 127.216369, "con":0},
    {"line": "05호선", "name": "방화", "code": 2511,
        "lat": 37.577446, "lng": 126.812741, "con":0},
    {"line": "05호선", "name": "개화산", "code": 2512,
        "lat": 37.572399, "lng": 126.806171, "con":4.8},
    {"line": "05호선", "name": "김포공항", "code": 2513,
        "lat": 37.562434, "lng": 126.801058, "con":9.9},
    {"line": "05호선", "name": "송정", "code": 2514,
        "lat": 37.561184, "lng": 126.811973, "con":17.8},
    {"line": "05호선", "name": "마곡", "code": 2515,
        "lat": 37.560183, "lng": 126.825448, "con":19.1},
    {"line": "05호선", "name": "애오개", "code": 2531,
        "lat": 37.553736, "lng": 126.95682, "con":47.3},
    {"line": "05호선", "name": "서대문", "code": 2533,
        "lat": 37.565773, "lng": 126.966641, "con":46.4},
    {"line": "05호선", "name": "광화문", "code": 2534,
        "lat": 37.571026, "lng": 126.976669, "con":56.6},
    {"line": "05호선", "name": "충정로", "code": 2532,
        "lat": 37.559973, "lng": 126.963672, "con":47.2},
    {"line": "05호선", "name": "왕십리", "code": 2541,
        "lat": 37.561533, "lng": 127.037732, "con":69.5},
    {"line": "05호선", "name": "발산", "code": 2516,
        "lat": 37.558598, "lng": 126.837668, "con":23.4},
    {"line": "05호선", "name": "우장산", "code": 2517,
        "lat": 37.548768, "lng": 126.836318, "con":40.7},
    {"line": "05호선", "name": "화곡", "code": 2518,
        "lat": 37.541513, "lng": 126.840461, "con":42.4},
    {"line": "05호선", "name": "까치산", "code": 2519,
        "lat": 37.531768, "lng": 126.846683, "con":39.9},
    {"line": "05호선", "name": "신정", "code": 2520,
        "lat": 37.524997, "lng": 126.856191, "con":25.4},
    {"line": "05호선", "name": "목동", "code": 2521,
        "lat": 37.526065, "lng": 126.864931, "con":24.2},
    {"line": "05호선", "name": "오목교", "code": 2522,
        "lat": 37.524496, "lng": 126.875181, "con":24.1},
    {"line": "05호선", "name": "양평", "code": 2523,
        "lat": 37.492832, "lng": 127.491814, "con":29.2},
    {"line": "05호선", "name": "영등포구청", "code": 2524,
        "lat": 37.52497, "lng": 126.895951, "con":31.8},
    {"line": "05호선", "name": "영등포시장", "code": 2525,
        "lat": 37.522669, "lng": 126.905139, "con":22},
    {"line": "05호선", "name": "신길", "code": 2526,
        "lat": 37.517122, "lng": 126.917169, "con":24.2},
    {"line": "05호선", "name": "여의도", "code": 2527,
        "lat": 37.521624, "lng": 126.924191, "con":26.3},
    {"line": "05호선", "name": "여의나루", "code": 2528,
        "lat": 37.527098, "lng": 126.932901, "con":50.3},
    {"line": "05호선", "name": "마포", "code": 2529,
        "lat": 37.539574, "lng": 126.945932, "con":57.9},
    {"line": "05호선", "name": "공덕", "code": 2530,
        "lat": 37.544018, "lng": 126.951592, "con":58.4},
    {"line": "05호선", "name": "을지로4가", "code": 2536,
        "lat": 37.566941, "lng": 126.998079, "con":73.2},
    {"line": "05호선", "name": "신금호", "code": 2539,
        "lat": 37.554548, "lng": 127.020331, "con":75.6},
    {"line": "05호선", "name": "행당", "code": 2540,
        "lat": 37.557322, "lng": 127.029476, "con":73.5},
    {"line": "05호선", "name": "마장", "code": 2542,
        "lat": 37.5661, "lng": 127.042973, "con":89.8},
    {"line": "05호선", "name": "답십리", "code": 2543,
        "lat": 37.566747, "lng": 127.052704, "con":88},
    {"line": "05호선", "name": "장한평", "code": 2544,
        "lat": 37.56144, "lng": 127.064623, "con":81.5},
    {"line": "05호선", "name": "군자", "code": 2545,
        "lat": 37.557121, "lng": 127.079542, "con":80.6},
    {"line": "05호선", "name": "아차산", "code": 2546,
        "lat": 37.551691, "lng": 127.089761, "con":87.5},
    {"line": "05호선", "name": "광나루", "code": 2547,
        "lat": 37.545303, "lng": 127.10357, "con":82},
    {"line": "05호선", "name": "천호", "code": 2548,
        "lat": 37.538397, "lng": 127.123572, "con":76.8},
    {"line": "05호선", "name": "강동", "code": 2549,
        "lat": 37.535804, "lng": 127.132481, "con":7.},
    {"line": "05호선", "name": "길동", "code": 2550,
        "lat": 37.537801, "lng": 127.140004, "con":89.1},
    {"line": "05호선", "name": "굽은다리", "code": 2551,
        "lat": 37.545477, "lng": 127.142853, "con":78.9},
    {"line": "05호선", "name": "명일", "code": 2552,
        "lat": 37.55137, "lng": 127.143999, "con":61},
    {"line": "05호선", "name": "고덕", "code": 2553,
        "lat": 37.555004, "lng": 127.154151, "con":45.8},
    {"line": "05호선", "name": "상일동", "code": 2554,
        "lat": 37.556712, "lng": 127.166417, "con":31.4},
    {"line": "05호선", "name": "방이", "code": 2557,
        "lat": 37.508857, "lng": 127.126133, "con":48.5},
    {"line": "05호선", "name": "오금", "code": 2558,
        "lat": 37.502162, "lng": 127.128111, "con":42.7},
    {"line": "05호선", "name": "개롱", "code": 2559,
        "lat": 37.498079, "lng": 127.13482, "con":45.3},
    {"line": "05호선", "name": "거여", "code": 2560,
        "lat": 37.493105, "lng": 127.14415, "con":22.7},
    {"line": "05호선", "name": "마천", "code": 2561,
        "lat": 37.49499, "lng": 127.152781, "con":10.7},
    {"line": "05호선", "name": "동대문역사문화공원", "code": 2537,
        "lat": 37.565138, "lng": 127.007896, "con":74},
    {"line": "05호선", "name": "청구", "code": 2538,
        "lat": 37.560245, "lng": 127.013828, "con":73.6}
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)
# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['con']
    # 색상 설정
    if reservoir_ratio >80:
       fill_color = 'red'
    elif reservoir_ratio > 40:
       fill_color = 'orange'
    elif reservoir_ratio >0:
       fill_color = 'green'
    elif reservoir_ratio ==0:
       fill_color='gray'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['con']}
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)

m
