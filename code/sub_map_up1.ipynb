# %%
import folium
import pandas as pd

# 데이터 준비
data = [
    {"line": "01호선", "name": "녹양", "code": 1908,
        "lat": 37.75938, "lng": 127.042292, "lev": 0},
    {"line": "01호선", "name": "남영", "code": 1002, "lat": 37.541021, "lng": 126.9713, "lev": 0},
    {"line": "01호선", "name": "용산", "code": 1003,
        "lat": 37.529849, "lng": 126.964561 , "lev": 0},
    {"line": "01호선", "name": "노량진", "code": 1004,
        "lat": 37.514219, "lng": 126.942454, "lev": 0},
    {"line": "01호선", "name": "대방", "code": 1005,
        "lat": 37.513342, "lng": 126.926382, "lev": 0},
    {"line": "01호선", "name": "영등포", "code": 1006,
        "lat": 37.515504, "lng": 126.907628, "lev": 0},
    {"line": "01호선", "name": "신도림", "code": 1007,
        "lat": 37.508725, "lng": 126.891295, "lev": 0},
    {"line": "01호선", "name": "회기", "code": 1015,
        "lat": 37.58946, "lng": 127.057583, "lev": 0},
    {"line": "01호선", "name": "외대앞", "code": 1016,
        "lat": 37.596073, "lng": 127.063549, "lev": 0},
    {"line": "01호선", "name": "신이문", "code": 1017,
        "lat": 37.601854, "lng": 127.067325, "lev": 0},
    {"line": "01호선", "name": "광운대", "code": 1019,
        "lat": 37.623632, "lng": 127.061835, "lev": 0},
    {"line": "01호선", "name": "월계", "code": 1020,
        "lat": 37.633212, "lng": 127.058831, "lev": 0},
    {"line": "01호선", "name": "녹천", "code": 1021,
        "lat": 37.644799, "lng": 127.051269, "lev": 0},
    {"line": "01호선", "name": "창동", "code": 1022,
        "lat": 37.653166, "lng": 127.047731, "lev": 0},
    {"line": "01호선", "name": "신길", "code": 1032,
        "lat": 37.517122, "lng": 126.917169, "lev": 0},
    {"line": "01호선", "name": "석계", "code": 1018,
        "lat": 37.614805, "lng": 127.065851, "lev": 0},
    {"line": "01호선", "name": "봉명", "code": 1401,
        "lat": 36.801215, "lng": 127.135763, "lev": 0},
    {"line": "01호선", "name": "쌍용", "code": 1402, "lat": 36.793759, "lng": 127.1214, "lev": 0},
    {"line": "01호선", "name": "아산", "code": 1403,
        "lat": 36.792053, "lng": 127.104361, "lev": 0},
    {"line": "01호선", "name": "배방", "code": 1405,
        "lat": 36.777629, "lng": 127.052991, "lev": 0},
    {"line": "01호선", "name": "온양온천", "code": 1407,
        "lat": 36.780483, "lng": 127.003249, "lev": 0},
    {"line": "01호선", "name": "신창", "code": 1408,
        "lat": 36.769502, "lng": 126.951108, "lev": 0},
    {"line": "01호선", "name": "구로", "code": 1701,
        "lat": 37.503039, "lng": 126.881966, "lev": 0},
    {"line": "01호선", "name": "가산디지털단지", "code": 1702,
        "lat": 37.481072, "lng": 126.882343, "lev": 0},
    {"line": "01호선", "name": "금천구청", "code": 1703,
        "lat": 37.455626, "lng": 126.89398, "lev": 0},
    {"line": "01호선", "name": "관악", "code": 1705,
        "lat": 37.419232, "lng": 126.908706, "lev": 0},
    {"line": "01호선", "name": "안양", "code": 1706,
        "lat": 37.401592, "lng": 126.922874, "lev": 0},
    {"line": "01호선", "name": "명학", "code": 1707,
        "lat": 37.384653, "lng": 126.935433, "lev": 0},
    {"line": "01호선", "name": "금정", "code": 1708,
        "lat": 37.372221, "lng": 126.943429, "lev": 0},
    {"line": "01호선", "name": "의왕", "code": 1710,
        "lat": 37.320852, "lng": 126.948217, "lev": 0},
    {"line": "01호선", "name": "성균관대", "code": 1711,
        "lat": 37.300349, "lng": 126.97075, "lev": 0},
    {"line": "01호선", "name": "석수", "code": 1704,
        "lat": 37.435047, "lng": 126.902295, "lev": 0},
    {"line": "01호선", "name": "화서", "code": 1712,
        "lat": 37.283862, "lng": 126.989627, "lev": 0},
    {"line": "01호선", "name": "수원", "code": 1713,
        "lat": 37.265974, "lng": 126.999874, "lev": 0},
    {"line": "01호선", "name": "독산", "code": 1714,
        "lat": 37.466613, "lng": 126.889249, "lev": 0},
    {"line": "01호선", "name": "세류", "code": 1715,
        "lat": 37.245025, "lng": 127.013222, "lev": 0},
    {"line": "01호선", "name": "병점", "code": 1716,
        "lat": 37.207503, "lng": 127.032731, "lev": 0},
    {"line": "01호선", "name": "세마", "code": 1717,
        "lat": 37.187533, "lng": 127.04318, "lev": 0},
    {"line": "01호선", "name": "오산대", "code": 1718,
        "lat": 37.168953, "lng": 127.063197, "lev": 0},
    {"line": "01호선", "name": "송탄", "code": 1721,
        "lat": 37.075696, "lng": 127.054301, "lev": 0},
    {"line": "01호선", "name": "서정리", "code": 1722,
        "lat": 37.056496, "lng": 127.052819, "lev": 0},
    {"line": "01호선", "name": "평택", "code": 1724,
        "lat": 36.990726, "lng": 127.085159, "lev": 0},
    {"line": "01호선", "name": "성환", "code": 1725,
        "lat": 36.916076, "lng": 127.126964, "lev": 0},
    {"line": "01호선", "name": "직산", "code": 1726,
        "lat": 36.870593, "lng": 127.143904, "lev": 0},
    {"line": "01호선", "name": "두정", "code": 1727,
        "lat": 36.833705, "lng": 127.14896, "lev": 0},
    {"line": "01호선", "name": "천안", "code": 1728,
        "lat": 36.810005, "lng": 127.146826, "lev": 0},
    {"line": "01호선", "name": "광명", "code": 1750,
        "lat": 37.416182, "lng": 126.884466, "lev": 0},
    {"line": "01호선", "name": "개봉", "code": 1801,
        "lat": 37.494594, "lng": 126.85868, "lev": 0},
    {"line": "01호선", "name": "오류동", "code": 1802,
        "lat": 37.494526, "lng": 126.845365, "lev": 0},
    {"line": "01호선", "name": "역곡", "code": 1803,
        "lat": 37.485178, "lng": 126.811502, "lev": 0},
    {"line": "01호선", "name": "군포", "code": 1709,
        "lat": 37.35356, "lng": 126.948462, "lev": 0},
    {"line": "01호선", "name": "당정", "code": 1729,
        "lat": 37.344285, "lng": 126.948345, "lev": 0},
    {"line": "01호선", "name": "서동탄", "code": 1749,
        "lat": 37.195504, "lng": 127.051672, "lev": 0},
    {"line": "01호선", "name": "부천", "code": 1804,
        "lat": 37.48405, "lng": 126.782686, "lev": 0},
    {"line": "01호선", "name": "송내", "code": 1805, "lat": 37.4876, "lng": 126.753664, "lev": 0},
    {"line": "01호선", "name": "부평", "code": 1806,
        "lat": 37.489493, "lng": 126.724805, "lev": 0},
    {"line": "01호선", "name": "백운", "code": 1807,
        "lat": 37.483664, "lng": 126.707704, "lev": 0},
    {"line": "01호선", "name": "주안", "code": 1809,
        "lat": 37.464941, "lng": 126.679923, "lev": 0},
    {"line": "01호선", "name": "제물포", "code": 1810,
        "lat": 37.466769, "lng": 126.656666, "lev": 0},
    {"line": "01호선", "name": "동인천", "code": 1811,
        "lat": 37.475276, "lng": 126.632802, "lev": 0},
    {"line": "01호선", "name": "인천", "code": 1812,
        "lat": 37.476691, "lng": 126.616936, "lev": 0},
    {"line": "01호선", "name": "구일", "code": 1813,
        "lat": 37.496756, "lng": 126.870793, "lev": 0},
    {"line": "01호선", "name": "소사", "code": 1814,
        "lat": 37.482753, "lng": 126.79544, "lev": 0},
    {"line": "01호선", "name": "부개", "code": 1815,
        "lat": 37.488418, "lng": 126.74109, "lev": 0},
    {"line": "01호선", "name": "간석", "code": 1816,
        "lat": 37.464737, "lng": 126.694181, "lev": 0},
    {"line": "01호선", "name": "도원", "code": 1817,
        "lat": 37.468446, "lng": 126.642706, "lev": 0},
    {"line": "01호선", "name": "온수", "code": 1821,
        "lat": 37.492258, "lng": 126.823388, "lev": 0},
    {"line": "01호선", "name": "중동", "code": 1822,
        "lat": 37.486562, "lng": 126.764843, "lev": 0},
    {"line": "01호선", "name": "오산", "code": 1719,
        "lat": 37.145885, "lng": 127.06672, "lev": 0},
    {"line": "01호선", "name": "진위", "code": 1720,
        "lat": 37.109447, "lng": 127.062278, "lev": 0},
    {"line": "01호선", "name": "동암", "code": 1808,
        "lat": 37.471408, "lng": 126.702896, "lev": 0},
    {"line": "01호선", "name": "도화", "code": 1823,
        "lat": 37.46607, "lng": 126.668672, "lev": 0},
    {"line": "01호선", "name": "방학", "code": 1901,
        "lat": 37.667503, "lng": 127.044273, "lev": 0},
    {"line": "01호선", "name": "도봉", "code": 1902,
        "lat": 37.679563, "lng": 127.045595, "lev": 0},
    {"line": "01호선", "name": "도봉산", "code": 1903,
        "lat": 37.689313, "lng": 127.046222, "lev": 0},
    {"line": "01호선", "name": "망월사", "code": 1904,
        "lat": 37.709914, "lng": 127.047455, "lev": 0},
    {"line": "01호선", "name": "회룡", "code": 1905,
        "lat": 37.724846, "lng": 127.046895, "lev": 0},
    {"line": "01호선", "name": "의정부", "code": 1906,
        "lat": 37.738415, "lng": 127.045958, "lev": 0},
    {"line": "01호선", "name": "가능", "code": 1907,
        "lat": 37.748577, "lng": 127.044213, "lev": 0},
    {"line": "01호선", "name": "양주", "code": 1909,
        "lat": 37.774381, "lng": 127.044708, "lev": 0},
    {"line": "01호선", "name": "덕계", "code": 1910,
        "lat": 37.818486, "lng": 127.056486, "lev": 0},
    {"line": "01호선", "name": "덕정", "code": 1911,
        "lat": 37.843188, "lng": 127.061277, "lev": 0},
    {"line": "01호선", "name": "지행", "code": 1912,
        "lat": 37.892334, "lng": 127.055716, "lev": 0},
    {"line": "01호선", "name": "동두천중앙", "code": 1913,
        "lat": 37.901885, "lng": 127.056482, "lev": 0},
    {"line": "01호선", "name": "동두천", "code": 1915,
        "lat": 37.927878, "lng": 127.05479, "lev": 0},
    {"line": "01호선", "name": "보산", "code": 1914,
        "lat": 37.913702, "lng": 127.057277, "lev": 0},
    {"line": "01호선", "name": "종로3가", "code": 153,
        "lat": 37.571607, "lng": 126.991806, "lev": 36.2},
    {"line": "01호선", "name": "종로5가", "code": 154,
        "lat": 37.570926, "lng": 127.001849, "lev":70.8},
    {"line": "01호선", "name": "동대문", "code": 155,
        "lat": 37.57142, "lng": 127.009745, "lev":26.1},
    {"line": "01호선", "name": "신설동", "code": 156,
        "lat": 37.575297, "lng": 127.025087, "lev":17.6},
    {"line": "01호선", "name": "제기동", "code": 157,
        "lat": 37.578103, "lng": 127.034893,"lev":14.3},
    {"line": "01호선", "name": "청량리", "code": 158,
        "lat": 37.580178, "lng": 127.046835,"lev":12.2},
    {"line": "01호선", "name": "동묘앞", "code": 159,
        "lat": 37.572627, "lng": 127.016429,"lev":22.7},
    {"line": "01호선", "name": "소요산", "code": 1916,
        "lat": 37.9481, "lng": 127.061034, "lev": 0},
    {"line": "01호선", "name": "지제", "code": 1723, "lat": 37.0188, "lng": 127.070444, "lev": 0},
    {"line": "01호선", "name": "서울역", "code": 150,
        "lat": 37.554648, "lng": 126.972559, "lev": 70},
    {"line": "01호선", "name": "시청", "code": 151,
        "lat": 37.564718, "lng": 126.977108, "lev": 53.7},
    {"line": "01호선", "name": "종각", "code": 152,
        "lat": 37.570161, "lng": 126.982923, "lev": 34.8}  
]

# 지도 객체 생성
m = folium.Map(location=[37.508725,126.891295], zoom_start=10)
# 데이터를 지도에 추가
for item in data:
    lat1 = item['lat']
    lon = item['lng']
    reservoir_ratio = item['lev']
    # 색상 설정
    if reservoir_ratio >= 60:
       fill_color = 'red'
    elif 60>reservoir_ratio>=40:
       fill_color = 'orange'
    elif reservoir_ratio==0:
      fill_color = 'gray'
    else:
        fill_color='green'
    # 팝업 텍스트 설정
    popup_text = f"""
        <b>호선: </b>{item['line']}<br><b>역 이름: </b>{item['name']}<br>
        <b>외부코드: </b>{item['code']}<br><b>위도: </b>{item['lat']}<br>
        <b>경도: </b>{item['lng']}<br><b>혼잡도: </b>{item['lev']}<br>
    """
    # 팝업 텍스트 크기 조정
    popup = folium.Popup(popup_text, max_width=400)
    # 마커 생성 및 지도에 추가
    marker = folium.CircleMarker(
        location=[lat1, lon],
        radius=10,
        color='black',
        fill_color=fill_color,
        fill_opacity=0.7,
        popup=popup
    )
    marker.add_to(m)
# 지도 표시
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
